# %% [markdown]
# <a href="https://colab.research.google.com/github/AlienX77-cmd/Python-for-Business-and-Finance/blob/main/Exercise_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# Now, you will have the opportunity to practice what you have learned. <br>
# __Follow the instructions__ and insert your code!

# %% [markdown]
# The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need some help or if you want to check your code, you can also have a look at the __solutions__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Exercise 6: How to create great graphs with Matplotlib

# %% [markdown]
# 1. Before you can start, you have to __import__ matplotlib.pyplot!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You consider an investment with the following cashflows:
#
# - -5,000 USD today (Investment)
# - 1,200 USD in 1 year
# - 1,500 USD in 2 years
# - 2,000 USD in 3 years
# - 2,500 USD in 4 years
# - 3,000 USD in 5 years
# - 3,500 USD in 6 years

# %%
# run the cell!
cf = [-5000, 1200, 1500, 2000, 2500, 3000, 2500]
cf
# Out:
# [-5000, 1200, 1500, 2000, 2500, 3000, 2500]

# %% [markdown]
# 2. Create one __list with cumulative cashflows__ and one __list with timestamps__!

# %%
cf_cum = []
cum = 0
for i in range(len(cf)):
  cum += cf[i]
  cf_cum.append(cum)
cf_cum
# Out:
# [-5000, -3800, -2300, -300, 2200, 5200, 7700]

# %%
ts = list(range(len(cf)))
ts
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# 3. Visualize __cumulative cashflows__ in a simple __line plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize = (12, 8))
plt.plot(cf_cum)
plt.show()

# %% [markdown]
# 4. Visualize __cumulative cashflows__ in a simple __scatter plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize = (12, 8))
plt.scatter(x = ts, y = cf_cum)
plt.show()

# %% [markdown]
# 5. __Customize__ the plot! (see final result below)

# %%
#complete the code!

plt.figure(figsize = (12, 8))
plt.plot([-5000, -3800, -2300, -300, 2200, 5200, 7700], color = "red", linestyle = "--", marker = "D", markersize = 10, label = "Cumulative Cashflows")
plt.grid()
plt.hlines(y = 0, xmin = ts[0], xmax = ts[-1], linestyles = "solid", color = "blue", label = "Break Even")
plt.title("Cumulative Cashflows Project A", fontsize = 15)
plt.xlabel("Time (Years)", fontsize = 12)
plt.ylabel("Cashflows (USD)", fontsize = 12)
plt.yticks(range(-6000, 8001, 1000)) #min = -6000, max = 8000, step = 1000
plt.xticks(ts, labels = ["t0", "t1", "t2", "t3", "t4", "t5", "t6"])
plt.annotate("Break Even Point", xy = (3.1, 0), xytext= (2.5, 2000), arrowprops = {"color": "black"}, fontsize = 15)
plt.legend(loc = "best", fontsize = 15)
plt.show()

# %% [markdown]
# # Well Done!

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Solutions (Stop here if you want to code on your own!)

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# 1. Before you can start, you have to __import__ matplotlib.pyplot!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You consider an investment with the following cashflows:
#
# - -5,000 USD today (Investment)
# - 1,200 USD in 1 year
# - 1,500 USD in 2 years
# - 2,000 USD in 3 years
# - 2,500 USD in 4 years
# - 3,000 USD in 5 years
# - 3,500 USD in 6 years

# %%
# run the cell!
cf = [-5000, 1200, 1500, 2000, 2500, 3000, 2500]
cf
# Out:
# [-5000, 1200, 1500, 2000, 2500, 3000, 2500]

# %% [markdown]
# 2. Create one __list with cumulative cashflows__ and one __list with timestamps__!

# %%
cf_cum = []
cumul = 0
for i in cf:
    cumul += i
    cf_cum.append(cumul)
cf_cum
# Out:
# [-5000, -3800, -2300, -300, 2200, 5200, 7700]

# %%
x = [0, 1, 2, 3, 4, 5, 6]
x
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# 3. Visualize __cumulative cashflows__ in a simple __line plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize = (12, 8))
plt.plot(cf_cum)
plt.show()

# %% [markdown]
# 4. Visualize __cumulative cashflows__ in a simple __scatter plot__! (figure size: (12, 8)) (see result below)

# %%
plt.figure(figsize = (12, 8))
plt.scatter(x = x, y = cf_cum)
plt.show()

# %% [markdown]
# 5. __Customize__ the plot! (see final result below)

# %%
#complete the code!

plt.figure(figsize = (12, 8))
plt.plot([-5000, -3800, -2300, -300, 2200, 5200, 7700], color = "red", linestyle = "-.", marker = "D", markersize = 10, label = "Cumulative Cashflows")
plt.grid()
plt.hlines(y = 0, xmin = x[0], xmax = x[-1], linestyles= "solid", color = "blue", label = "Break Even")
plt.title("Cumulative Cashflows Project B", fontsize = 15)
plt.xlabel("Time (in Years)", fontsize = 12)
plt.ylabel("CF (in USD)", fontsize = 12)
plt.yticks(range(-6000,8001,1000))
plt.xticks(x, labels = ["t0", "t1", "t2", "t3", "t4", "t5", "t6"])
plt.annotate("Break Even Point", xy = (3.1, 0),xytext = (2.5, 2000), arrowprops= {"color":"black"}, fontsize = 15)
plt.legend(loc = "best", fontsize = 15)
plt.show()
